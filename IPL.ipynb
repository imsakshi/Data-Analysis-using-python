# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("matches.csv")

# %%
df.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
df1 = pd.read_csv("matches.csv")

# %%
df1.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
toss_winner=df1[df1['toss_winner']==df1['winner']]
toss_winner.count()['id']
# Out:
# 325

# %%
dt=df1['venue'].value_counts().head(7)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig=plt.figure(figsize=(10,10))
dt.plot(kind="barh",fontsize=20)
plt.ylabel("Location names",fontsize=50,color="red",fontweight='bold')
#plt.title("LOCATION VS RESTAURANT COUNT GRAPH",fontsize=40,color="BLACK")
plt.show()

# %%
df['venue'].value_counts()[:7]
# Out:
# M Chinnaswamy Stadium                         66
# Eden Gardens                                  61
# Feroz Shah Kotla                              60
# Wankhede Stadium                              57
# Rajiv Gandhi International Stadium, Uppal     49
# MA Chidambaram Stadium, Chepauk               48
# Punjab Cricket Association Stadium, Mohali    35
# Name: venue, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 7 Most Played venue in the History of IPL from 2008 to 2017¶

# %%
sns.set_style("darkgrid")# to make background with grid
ls=df1['venue'].value_counts().sort_values(ascending=False)
ls=ls[:7]
plt.figure(figsize=(20,6))
Most_Played =sns.barplot(ls.index, ls.values)

plt.title('Most Played venue')
plt.ylabel('Count', fontsize=12)
plt.xlabel('Name of the stadiums', fontsize=15)
Most_Played.set_xticklabels(rotation=30,labels=ls.index,fontsize=10)
plt.show()

# %%
ls
# Out:
# M Chinnaswamy Stadium                         66
# Eden Gardens                                  61
# Feroz Shah Kotla                              60
# Wankhede Stadium                              57
# Rajiv Gandhi International Stadium, Uppal     49
# MA Chidambaram Stadium, Chepauk               48
# Punjab Cricket Association Stadium, Mohali    35
# Name: venue, dtype: int64

# %%
ls.index
# Out:
# Index(['M Chinnaswamy Stadium', 'Eden Gardens', 'Feroz Shah Kotla',
#        'Wankhede Stadium', 'Rajiv Gandhi International Stadium, Uppal',
#        'MA Chidambaram Stadium, Chepauk',
#        'Punjab Cricket Association Stadium, Mohali'],
#       dtype='object')

# %%
ls.values
# Out:
# array([66, 61, 60, 57, 49, 48, 35], dtype=int64)

# %%
Delhi_stadium=df1.loc[(df1['venue']=='Feroz Shah Kotla') ]
Delhi_stadium_win_by_runs=Delhi_stadium[Delhi_stadium['win_by_runs']>0]# As it is  win by runs this depicts Team batting First Has Won the match
slices=[len(Delhi_stadium_win_by_runs),len(Delhi_stadium)-len(Delhi_stadium_win_by_runs)]
labels=['Batting first','Batting Second']
plt.pie(slices,labels=labels,startangle=90,shadow=1,explode=(0,0.4),autopct='%1.2f%%',colors=['#bf00ff','#66CDAA'])
plt.show()

# %%
Delhi_stadium=df1.loc[(df1['venue']=='M Chinnaswamy Stadium') ]
Delhi_stadium_win_by_runs=Delhi_stadium[Delhi_stadium['win_by_runs']>0]# As it is  win by runs this depicts Team batting First Has Won the match
slices=[len(Delhi_stadium_win_by_runs),len(Delhi_stadium)-len(Delhi_stadium_win_by_runs)]
labels=['Batting first','Batting Second']
plt.pie(slices,labels=labels,startangle=90,shadow=1,explode=(0,0.4),autopct='%1.2f%%',colors=['#bf00ff','#66CDAA'])
plt.show()

# %%
slices
# Out:
# [27, 39]

# %%
Delhi_stadium=df1.loc[(df1['venue']=='Feroz Shah Kotla') ]

# %%
Delhi_stadium.head()

# %%
Delhi_stadium.result.value_counts()

# %%
Delhi_stadium_win_by_runs=Delhi_stadium[Delhi_stadium['win_by_runs']>0]

# %%
Delhi_stadium_win_by_runs

# %%
slices=[len(Delhi_stadium_win_by_runs),len(Delhi_stadium)-len(Delhi_stadium_win_by_runs)]

# %%
slices

# %%
labels=['Batting first','Batting Second']

# %%
plt.pie(slices,labels=labels,startangle=90,shadow=1,explode=(0,0),autopct='%1.2f%%',colors=['#bf00ff','#66CDAA'])

# %%
match_2017=df1[df1['season']==2017]
df=match_2017[match_2017['toss_winner']==match_2017['winner']]
slices=[len(df),(59-len(df))]# because Toal 59 matches were played in 2017
labels=['yes','no']
plt.pie(slices,labels=labels,startangle=90,shadow=True,explode=(0,0.05),autopct='%1.2f%%',colors=['#99ff99','#ffcc99'])
plt.show()

# %%
match_2017
# Out:
#     id  season        city        date                        team1  \
# 0    1    2017   Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1    2    2017        Pune  2017-04-06               Mumbai Indians
# 2    3    2017      Rajkot  2017-04-07                Gujarat Lions
# 3    4    2017      Indore  2017-04-08       Rising Pune Supergiant
# 4    5    2017   Bangalore  2017-04-08  Royal Challengers Bangalore
# 5    6    2017   Hyderabad  2017-04-09                Gujarat Lions
# 6    7    2017      Mumbai  2017-04-09        Kolkata Knight Riders
# 7    8    2017      Indore  2017-04-10  Royal Challengers Bangalore
# 8    9    2017        Pune  2017-04-11             Delhi Daredevils
# 9   10    2017      Mumbai  2017-04-12          Sunrisers Hyderabad
# 10  11    2017     Kolkata  2017-04-13              Kings XI Punjab
# 11  12    2017   Bangalore  2017-04-14  Royal Challengers Bangalore
# 12  13    2017      Rajkot  2017-04-14       Rising Pune Supergiant
# ...

# %%
df=match_2017[match_2017['toss_winner']==match_2017['winner']]

# %%
df
# Out:
#     id  season        city        date                        team1  \
# 1    2    2017        Pune  2017-04-06               Mumbai Indians
# 2    3    2017      Rajkot  2017-04-07                Gujarat Lions
# 3    4    2017      Indore  2017-04-08       Rising Pune Supergiant
# 4    5    2017   Bangalore  2017-04-08  Royal Challengers Bangalore
# 5    6    2017   Hyderabad  2017-04-09                Gujarat Lions
# 6    7    2017      Mumbai  2017-04-09        Kolkata Knight Riders
# 9   10    2017      Mumbai  2017-04-12          Sunrisers Hyderabad
# 10  11    2017     Kolkata  2017-04-13              Kings XI Punjab
# 11  12    2017   Bangalore  2017-04-14  Royal Challengers Bangalore
# 12  13    2017      Rajkot  2017-04-14       Rising Pune Supergiant
# 14  15    2017       Delhi  2017-04-15             Delhi Daredevils
# 15  16    2017      Mumbai  2017-04-16                Gujarat Lions
# 20  21    2017   Hyderabad  2017-04-19          Sunrisers Hyderabad
# ...

# %%
slices=[len(df),(59-len(df))]

# %%
slices
# Out:
# [34, 25]

# %%
dfs=df1[(df1['toss_decision']=='field') & (df1['season']==2017) ]
labels=['Bat','Field']
slices=[59-len(dfs),len(dfs)]
plt.pie(slices,labels=labels,startangle=90,shadow=1,explode=(0.2,0.4),autopct='%1.2f%%',colors=['#ff9999','#66b3ff'])
plt.show()

# %%
df2 = pd.read_csv("deliveries.csv")

# %%
df2.head()

# %%
df2.info()

# %%
df2 = pd.read_csv("matches.csv")

# %% [markdown]
# How many matche we have got in the dataset?

# %%
df2["id"].max()
# Out:
# 636

# %%
df2.count()['id']
# Out:
# 636

# %% [markdown]
# How many seasons we have got in the dataset?

# %%
df2['season'].nunique()
# Out:
# 10

# %%
df2['season'].value_counts()
# Out:
# 2013    76
# 2012    74
# 2011    73
# 2016    60
# 2014    60
# 2010    60
# 2017    59
# 2015    59
# 2008    58
# 2009    57
# Name: season, dtype: int64

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
# id                 636 non-null int64
# season             636 non-null int64
# city               629 non-null object
# date               636 non-null object
# team1              636 non-null object
# team2              636 non-null object
# toss_winner        636 non-null object
# toss_decision      636 non-null object
# result             636 non-null object
# dl_applied         636 non-null int64
# winner             633 non-null object
# win_by_runs        636 non-null int64
# win_by_wickets     636 non-null int64
# player_of_match    633 non-null object
# venue              636 non-null object
# umpire1            635 non-null object
# umpire2            635 non-null object
# umpire3            0 non-null float64
# dtypes: float64(1), int64(5), object(12)
# memory usage: 89.5+ KB

# %%
which team had won by max runs?

# %%
df2[df2['win_by_runs']==df2['win_by_runs'].max()]['winner']
# Out:
# 43    Mumbai Indians
# Name: winner, dtype: object

# %%
df2.iloc[df2["win_by_runs"].idxmax()]
# Out:
# id                               44
# season                         2017
# city                          Delhi
# date                     2017-05-06
# team1                Mumbai Indians
# team2              Delhi Daredevils
# toss_winner        Delhi Daredevils
# toss_decision                 field
# result                       normal
# dl_applied                        0
# winner               Mumbai Indians
# win_by_runs                     146
# win_by_wickets                    0
# player_of_match         LMP Simmons
# venue              Feroz Shah Kotla
# umpire1                 Nitin Menon
# umpire2                   CK Nandan
# umpire3                         NaN
# Name: 43, dtype: object

# %%
df2.iloc[0:10]["winner"]
# Out:
# 0            Sunrisers Hyderabad
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 4    Royal Challengers Bangalore
# 5            Sunrisers Hyderabad
# 6                 Mumbai Indians
# 7                Kings XI Punjab
# 8               Delhi Daredevils
# 9                 Mumbai Indians
# Name: winner, dtype: object

# %%
df2[df2.win_by_runs == df2.win_by_runs.max()]
# Out:
# 43    2017
# Name: season, dtype: int64

# %%
df2[df2["win_by_runs"]==146]["winner"]
# Out:
# 43    Mumbai Indians
# Name: winner, dtype: object

# %%
Which team had won by max wickets?

# %%
df2.iloc[df2["win_by_wickets"].idxmax()]
# Out:
# id                                                      3
# season                                               2017
# city                                               Rajkot
# date                                           2017-04-07
# team1                                       Gujarat Lions
# team2                               Kolkata Knight Riders
# toss_winner                         Kolkata Knight Riders
# toss_decision                                       field
# result                                             normal
# dl_applied                                              0
# winner                              Kolkata Knight Riders
# win_by_runs                                             0
# win_by_wickets                                         10
# player_of_match                                   CA Lynn
# venue              Saurashtra Cricket Association Stadium
# umpire1                                       Nitin Menon
# ...

# %%
Which season had most number of matches?

# %%
df2["season"].value_counts()[:1]
# Out:
# 2013    76
# Name: season, dtype: int64

# %%
sns.countplot(x = "season",data = df2)
plt.show()

# %%
The most successful ipl team?

# %%
data = df2.winner.value_counts()
sns.barplot(y = data.index,x = data, orient = "h")

# %%
q = df2["season"].value_counts()

# %%
q.index
# Out:
# Int64Index([2013, 2012, 2011, 2016, 2014, 2010, 2017, 2015, 2008, 2009], dtype='int64')

# %%
sns.countplot(x = q.index, data = q)

# %%
Top Player of the match winners?

# %%
top_players = df2.player_of_match.value_counts()[:10]

# %%
top_players
# Out:
# CH Gayle          18
# YK Pathan         16
# DA Warner         15
# AB de Villiers    15
# SK Raina          14
# RG Sharma         14
# G Gambhir         13
# MS Dhoni          13
# MEK Hussey        12
# AM Rahane         12
# Name: player_of_match, dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.barplot(y=top_players.index, x=top_players, orient='h')
plt.title("Top player of the match winners")
# Out:
# Text(0.5, 1.0, 'Top player of the match winners')

# %%
df=df2[df2['toss_winner']==df2['winner']]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 325 entries, 1 to 635
# Data columns (total 18 columns):
# id                 325 non-null int64
# season             325 non-null int64
# city               322 non-null object
# date               325 non-null object
# team1              325 non-null object
# team2              325 non-null object
# toss_winner        325 non-null object
# toss_decision      325 non-null object
# result             325 non-null object
# dl_applied         325 non-null int64
# winner             325 non-null object
# win_by_runs        325 non-null int64
# win_by_wickets     325 non-null int64
# player_of_match    325 non-null object
# venue              325 non-null object
# umpire1            324 non-null object
# umpire2            324 non-null object
# umpire3            0 non-null float64
# dtypes: float64(1), int64(5), object(12)
# memory usage: 48.2+ KB

# %%
  Match winners based on season?

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
# id                 636 non-null int64
# season             636 non-null int64
# city               629 non-null object
# date               636 non-null object
# team1              636 non-null object
# team2              636 non-null object
# toss_winner        636 non-null object
# toss_decision      636 non-null object
# result             636 non-null object
# dl_applied         636 non-null int64
# winner             633 non-null object
# win_by_runs        636 non-null int64
# win_by_wickets     636 non-null int64
# player_of_match    633 non-null object
# venue              636 non-null object
# umpire1            635 non-null object
# umpire2            635 non-null object
# umpire3            0 non-null float64
# dtypes: float64(1), int64(5), object(12)
# memory usage: 89.5+ KB

# %%
df2.groupby("season")["winner"].value_counts()
# Out:
# season  winner
# 2008    Rajasthan Royals               13
#         Kings XI Punjab                10
#         Chennai Super Kings             9
#         Delhi Daredevils                7
#         Mumbai Indians                  7
#         Kolkata Knight Riders           6
#         Royal Challengers Bangalore     4
#         Deccan Chargers                 2
# 2009    Delhi Daredevils               10
#         Deccan Chargers                 9
#         Royal Challengers Bangalore     9
#         Chennai Super Kings             8
#         Kings XI Punjab                 7
#         Rajasthan Royals                6
#         Mumbai Indians                  5
#         Kolkata Knight Riders           3
# 2010    Mumbai Indians                 11
#         Chennai Super Kings             9
#         Deccan Chargers                 8
#         Royal Challengers Bangalore     8
#         Delhi Daredevils                7
#         Kolkata Knight Riders           7
# ...

# %%
df2["date"].dtype
# Out:
# dtype('O')

# %%
df2["date"] = pd.to_datetime(df2["date"])

# %%
df2["date"].dtype
# Out:
# dtype('<M8[ns]')

# %%
df2["year"]=df2["date"].dt.day

# %%
df2.head()
# Out:
#    id  season       city       date                        team1  \
# 0   1    2017  Hyderabad 2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune 2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot 2017-04-07                Gujarat Lions
# 3   4    2017     Indore 2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore 2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
df = pd.DataFrame({"year":[2015,2016],
                    "month":[2,3],
                      "day" :[4,5]})

# %%
df
# Out:
#    year  month  day
# 0  2015      2    4
# 1  2016      3    5

# %%
pd.to_datetime(df)
# Out:
# 0   2015-02-04
# 1   2016-03-05
# dtype: datetime64[ns]
