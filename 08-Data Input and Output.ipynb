# %% [markdown]
# # Data Input and Output
#
# This notebook is the reference code for getting input and output, pandas can read a variety of file types using its pd.read_ methods. Let's take a look at the most common data types:

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## CSV
#
# ### CSV Input

# %%
df = pd.read_csv('911.csv')
df
# Out:
#              lat        lng  \
# 0      40.297876 -75.581294
# 1      40.258061 -75.264680
# 2      40.121182 -75.351975
# 3      40.116153 -75.343513
# 4      40.251492 -75.603350
# 5      40.253473 -75.283245
# 6      40.182111 -75.127795
# 7      40.217286 -75.405182
# 8      40.289027 -75.399590
# 9      40.102398 -75.291458
# 10     40.231990 -75.251891
# 11     40.084161 -75.308386
# 12     40.174131 -75.098491
# 13     40.062974 -75.135914
# 14     40.097222 -75.376195
# 15     40.223778 -75.235399
# 16     40.243258 -75.286552
# 17     40.312181 -75.574260
# 18     40.114239 -75.338508
# 19     40.209337 -75.135266
# 20     40.114239 -75.338508
# 21     40.117948 -75.209848
# 22     40.199006 -75.300058
# 23     40.143326 -75.422819
# 24     40.153268 -75.189558
# 25     40.133037 -75.408463
# 26     40.155283 -75.264230
# 27     40.028903 -75.351822
# 28     40.097222 -75.376195
# 29     40.209337 -75.135266
# ...          ...        ...
# 99462  40.274137 -75.660469
# ...

# %% [markdown]
# ### CSV Output

# %%
df.to_csv('example',index=False)

# %% [markdown]
# ## Excel
# Pandas can read and write excel files, keep in mind, this only imports data. Not formulas or images, having images or macros may cause this read_excel method to crash.

# %% [markdown]
# ### Excel Input

# %%
pd.read_excel('Excel_Sample.xlsx',sheetname='Sheet1')

# %% [markdown]
# ### Excel Output

# %%
df.to_excel('Excel_Sample.xlsx',sheet_name='Sheet1')

# %% [markdown]
# ## HTML
#
# You may need to install htmllib5,lxml, and BeautifulSoup4. In your terminal/command prompt run:
#
#     conda install lxml
#     conda install html5lib
#     conda install BeautifulSoup4
#
# Then restart Jupyter Notebook.
# (or use pip install if you aren't using the Anaconda Distribution)
#
# Pandas can read table tabs off of html. For example:

# %% [markdown]
# ### HTML Input
#
# Pandas read_html function will read tables off of a webpage and return a list of DataFrame objects:

# %%
import pandas as pd

# %%
df = pd.read_html('http://www.fdic.gov/bank/individual/failed/banklist.html')

# %%
df

# %%
a = df[0]

# %%
type(a)

# %% [markdown]
# ____

# %%
import sqlalchemy

# %%
# pip install mysql-connector-python

# %%
#write  conda install PyMySql--- to make connection with pandas+Mysql and refresh your jupyter page before running.

# %%
#conda install PyMySql

# %%
import pandas as pd

# %%
import pymysql

# %%
#To open mysql connection--pymysql.connect('host','user','password','Database name')

# %%
db = pymysql.connect('localhost','','','test')

# %%
df = pd.read_csv("salaries.csv")

# %%
df.to_sql(con=db, name='Table1', if_exists='replace')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1430             else:
# -> 1431                 cur.execute(*args)
#    1432             return cur
#
# C:\Anaconda3\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     167
# --> 168         query = self.mogrify(query, args)
#     169
#
# C:\Anaconda3\lib\site-packages\pymysql\cursors.py in mogrify(self, query, args)
#     146         if args is not None:
# --> 147             query = query % self._escape_args(args, conn)
#     148
#
# TypeError: not all arguments converted during string formatting
#
# During handling of the above exception, another exception occurred:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-12-38c34072e088> in <module>
# ...

# %%
df.to_sql("salary",db)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1430             else:
# -> 1431                 cur.execute(*args)
#    1432             return cur
#
# C:\Anaconda3\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     167
# --> 168         query = self.mogrify(query, args)
#     169
#
# C:\Anaconda3\lib\site-packages\pymysql\cursors.py in mogrify(self, query, args)
#     146         if args is not None:
# --> 147             query = query % self._escape_args(args, conn)
#     148
#
# TypeError: not all arguments converted during string formatting
#
# During handling of the above exception, another exception occurred:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-9-2113fb7c5f1d> in <module>
# ...

# %%
# prepare a cursor object using cursor() method
cursor = db.cursor()

# execute SQL query using execute() method.
cursor.execute("SELECT VERSION()")
# Out:
# 1

# %%
# Create table as per requirement
sql = """CREATE TABLE EMPLOYEE1 (
   FIRST_NAME  CHAR(20) NOT NULL,
   LAST_NAME  CHAR(20),
   AGE INT,  
   SEX CHAR(1),
   INCOME FLOAT )"""
cursor.execute(sql)
# Out:
# 0

# %%
sql = """INSERT INTO EMPLOYEE1(FIRST_NAME,
   LAST_NAME, AGE, SEX, INCOME)
   VALUES ('SHAKTI', 'Mohan', 20, 'M', 2000),
          ("SAKSHI","MANGA",25,"F",50000)"""

# %%
cursor.execute(sql)
   # Commit your changes in the database
db.commit()

# %%
import pandas as pd

# %%
df = pd.read_sql_query('select * from employee1',con = db)

# %%
df
# Out:
#   FIRST_NAME LAST_NAME  AGE SEX   INCOME
# 0     SHAKTI     Mohan   20   M   2000.0
# 1     SAKSHI     MANGA   25   F  50000.0

# %%
cursor.execute(sql)
   # Commit your changes in the database
db.commit()

# %%
sql = "select * from employee"

# %%
cursor.execute(sql)

# %%
results = cursor.fetchall()

# %%
results

# %%
import pandas as pd

# %%
df = pd.read_sql_query('select * from employee',con = db)

# %%
df
# Out:
#   FIRST_NAME LAST_NAME  AGE SEX  INCOME
# 0        Mac     Mohan   20   M  2000.0

# %%
df.to_csv("emp.csv")

# %%
import pymysql

# %%
db1 = pymysql.connect('localhost','root','','cms')

# %%
import pandas as pd

# %%
df1 = pd.read_sql_query("select * from customers",db1)

# %%
df1
# Out:
#    cust_id cust_name
# 0        1    sakshi
# 1        2    archna
# 2        3      love

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1.head()
# Out:
#    cust_id cust_name
# 0        1    sakshi
# 1        2    archna
# 2        3      love

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
# cust_id      3 non-null int64
# cust_name    3 non-null object
# dtypes: int64(1), object(1)
# memory usage: 128.0+ bytes

# %%
df1.describe()
# Out:
#        cust_id
# count      3.0
# mean       2.0
# std        1.0
# min        1.0
# 25%        1.5
# 50%        2.0
# 75%        2.5
# max        3.0

# %%
df1.isna().sum()
# Out:
# cust_id      0
# cust_name    0
# dtype: int64

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('sqlite:///:memory:')

# %%
df.to_sql('data', engine)

# %%
sql_df = pd.read_sql('data',con=engine)

# %%
sql_df

# %% [markdown]
# # Great Job!
